# %%
import pandas as pd

# %%
employee = pd.DataFrame({
    'emp_name': ['ashu', 'ashish', 'raj', 'raju', 'ram']
})

# %%
department = pd.DataFrame({
    'emp_names': ['ashu', 'raj', 'ram', 'ramu', 'bond'],
    'depart_name': ['IT', 'IT']
})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 department = pd.DataFrame({
#       2     'emp_names': ['ashu', 'raj', 'ram', 'ramu', 'bond'],
#       3     'depart_name': ['IT']
#       4 })
#
# File ~/Documents/code/python/.venv/lib/python3.14/site-packages/pandas/core/frame.py:782, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     776     mgr = self._init_mgr(
#     777         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     778     )
#     780 elif isinstance(data, dict):
#     781     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 782     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     783 elif isinstance(data, ma.MaskedArray):
#     784     from numpy.ma import mrecords
#
# ...
